# %%
# %load_ext autoreload
# %autoreload 2

# %%
from generation.instances import generate_instances

H = 7
S = 5
N = 25
amount = 1000
r = 100
seed = 41 + r

generate_instances(f"E5-25-{r}", H, S, N, amount, r, seed)

# %%
from generation.data import generate_data

H = 7
max_steps = 50

generate_data("E5-25-100", H, max_steps)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/E5-25-100.data (Tamaño 1000)

# %%
from preprocessing.dataset import generate_dataset

data_files = ["E5-25-3", "E5-25-10", "E5-25-20", "E5-25-50", "E5-25-100"]
min_cost = 5
max_cost = 14
max_size = 1500
output_name = f"E5-25-C{min_cost}-{max_cost}"

generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/E5-25-C5-14.data (Tamaño 1500)

# %%
from preprocessing.dataset import generate_dataset

data_files = ["E5-25-C5-14", "E5-25-C15-49"]
min_cost = 1
max_cost = 50
max_size = 30000
output_name = "E5-25"

generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/E5-25.data (Tamaño 3000)
