# %%
# %load_ext autoreload
# %autoreload 2

# %%
from models.cpmp_transformer import CPMPTransformer
from training.training import load_model

model_name = "v1"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver

instance_file = "benchmarks/data5-5-9.dat"
max_steps = 100
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps)

print(eval)
# Out:
# (True, 96)

# %%
from solvers.model import ModelSolver

folder = "benchmarks"
max_steps = 150
H = 7

solver = ModelSolver(model)
solved, steps = solver.solve_from_folder(folder, H, max_steps)

# %%
steps
# Out:
# [150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  147,
#  150,
#  150,
#  150,
#  150,
#  113,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  150,
#  128,
#  150,
#  150,
#  150,
#  150,
#  96,
#  150,
#  150,
#  150]
