# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from preprocessing.dataset import load_dataset

filename = "E5-25.data"
data = load_dataset(filename)
# Out:
# Dataset E5-25.data cargado con 3000 muestras.

# %%
from models.cpmp_transformer_v2 import CPMPTransformer

d_model = 32
nhead = 4
num_layers = 2
ff_dim_multiplier = 2
dropout = 0.1

model = CPMPTransformer(
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from models.cpmp_transformer_v2 import CPMPTransformer
#       2
#       3 d_model = 32
#       4 nhead = 4
#
# ImportError: cannot import name 'CPMPTransformer' from 'models.cpmp_transformer_v2' (/home/oscar/Escritorio/CPMP-Framework/src/models/cpmp_transformer_v2.py)

# %%
from training.training import train, Accuracy

epochs = 50
train_size = 2400
test_size = 600
batch_size = 32
learning_rate = 2e-4
weight_decay = 1e-4
patience = 10
metrics = [Accuracy()]
seed = 42

best_weights = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cpu
#
# Epoch 1/50
#     Average - Train Loss: 2.6933 | Val Loss: 2.6628
#  | Accuracy: 17.17%
# Epoch 2/50
#     Average - Train Loss: 2.6423 | Val Loss: 2.6515
#  | Accuracy: 15.50%
# Epoch 3/50
#     Average - Train Loss: 2.6269 | Val Loss: 2.6340
#  | Accuracy: 16.83%
# Epoch 4/50
#     Average - Train Loss: 2.6171 | Val Loss: 2.6231
#  | Accuracy: 16.67%
# Epoch 5/50
#     Average - Train Loss: 2.6029 | Val Loss: 2.6145
#  | Accuracy: 18.67%
# Epoch 6/50
#     Average - Train Loss: 2.5916 | Val Loss: 2.6047
#  | Accuracy: 18.00%
# Epoch 7/50
#     Average - Train Loss: 2.5915 | Val Loss: 2.5943
#  | Accuracy: 18.00%
# Epoch 8/50
#     Average - Train Loss: 2.5788 | Val Loss: 2.5926
#  | Accuracy: 16.83%
# Epoch 9/50
#     Average - Train Loss: 2.5763 | Val Loss: 2.5706
#  | Accuracy: 19.33%
# Epoch 10/50
#     Average - Train Loss: 2.5704 | Val Loss: 2.5744
#  | Accuracy: 17.67%
# Epoch 11/50
#     Average - Train Loss: 2.5607 | Val Loss: 2.5501
# ...

# %%
from training.training import save_model

save_model(model, "v1")
# Out:
# ✅ Modelo guardado en /home/oscar/Escritorio/CPMP-Framework/models/v1.pth
