# %%
# %load_ext autoreload
# %autoreload 2

# %%
from preprocessing.dataset import load_dataset

filename = "E5-25-42.data"
data = load_dataset(filename)
# Out:
# Dataset E5-25-42.data cargado con 500 muestras.

# %%
from models.cpmp_transformer_v3 import CPMPTransformer

H = 7
X_dim = 3
d_model = 32
nhead = 4
num_layers = 2
ff_dim_multiplier = 2
dropout = 0.2

model = CPMPTransformer(
    H=H,
    X_dim=X_dim,
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)

# %%
from training.training import train, Accuracy

epochs = 200
train_size = 400
test_size = 100
batch_size = 64
learning_rate = 2e-4
weight_decay = 1e-4
patience = 20
metrics = [Accuracy()]
seed = 42

model = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cpu
#
# Epoch 1/200
#     Average - Train Loss: 2.6552 | Val Loss: 2.6785
#  | Accuracy: 52.00%
# Epoch 2/200
#     Average - Train Loss: 2.6544 | Val Loss: 2.6785
#  | Accuracy: 57.00%
# Epoch 3/200
#     Average - Train Loss: 2.6547 | Val Loss: 2.6785
#  | Accuracy: 52.00%
# Epoch 4/200
#     Average - Train Loss: 2.6550 | Val Loss: 2.6785
#  | Accuracy: 49.00%
# Epoch 5/200
#     Average - Train Loss: 2.6545 | Val Loss: 2.6785
#  | Accuracy: 60.00%
# Epoch 6/200
#     Average - Train Loss: 2.6544 | Val Loss: 2.6785
#  | Accuracy: 58.00%
# Epoch 7/200
#     Average - Train Loss: 2.6548 | Val Loss: 2.6785
#  | Accuracy: 50.00%
# Epoch 8/200
#     Average - Train Loss: 2.6547 | Val Loss: 2.6785
#  | Accuracy: 50.00%
# Epoch 9/200
#     Average - Train Loss: 2.6545 | Val Loss: 2.6785
#  | Accuracy: 54.00%
# Epoch 10/200
#     Average - Train Loss: 2.6544 | Val Loss: 2.6785
#  | Accuracy: 56.00%
# Epoch 11/200
#     Average - Train Loss: 2.6547 | Val Loss: 2.6785
#  | Accuracy: 51.00%
# Epoch 12/200
#     Average - Train Loss: 2.6540 | Val Loss: 2.6785
#  | Accuracy: 51.00%
# Epoch 13/200
#     Average - Train Loss: 2.6548 | Val Loss: 2.6785
#  | Accuracy: 50.00%
# Epoch 14/200
#     Average - Train Loss: 2.6542 | Val Loss: 2.6785
#  | Accuracy: 52.00%
# Epoch 15/200
#     Average - Train Loss: 2.6537 | Val Loss: 2.6786
#  | Accuracy: 48.00%
# Epoch 16/200
#     Average - Train Loss: 2.6543 | Val Loss: 2.6789
#  | Accuracy: 52.00%
# Epoch 17/200
#     Average - Train Loss: 2.6542 | Val Loss: 2.6791
#  | Accuracy: 55.00%
# Epoch 18/200
#     Average - Train Loss: 2.6534 | Val Loss: 2.6796
#  | Accuracy: 53.00%
# Epoch 19/200
#     Average - Train Loss: 2.6537 | Val Loss: 2.6791
#  | Accuracy: 51.00%
# Epoch 20/200
#     Average - Train Loss: 2.6545 | Val Loss: 2.6788
#  | Accuracy: 56.00%
# Epoch 21/200
#     Average - Train Loss: 2.6547 | Val Loss: 2.6786
#  | Accuracy: 60.00%
# Epoch 22/200
#     Average - Train Loss: 2.6541 | Val Loss: 2.6787
#  | Accuracy: 57.00%
# Early stopping en época 22
# Mejor modelo (CrossEntropy): 2.6785 (Epoch 1)

# %%
from training.training import save_model

save_model(model, "v2")
# Out:
# ✅ Modelo guardado en /home/oscar/Escritorio/CPMP-Framework/models/v2.pth
