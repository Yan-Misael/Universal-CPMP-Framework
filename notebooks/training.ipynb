# %%
# %load_ext autoreload
# %autoreload 2

# %%
from preprocessing.dataset import load_dataset

filename = "E5-25-42.data"
data = load_dataset(filename)
# Out:
# Dataset E5-25-42.data cargado con 500 muestras.

# %%
from models.cpmp_transformer_v4 import CPMPTransformer

H = 7
C_dim = 3
X_dim = 3
d_model = 32
nhead = 4
num_layers = 2
ff_dim_multiplier = 2
dropout = 0.2

model = CPMPTransformer(
    H=H,
    C_dim=3,
    X_dim=X_dim,
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)

# %%
from training.training import train, Accuracy

epochs = 200
train_size = 400
test_size = 100
batch_size = 64
learning_rate = 2e-4
weight_decay = 1e-4
patience = 20
metrics = [Accuracy()]
seed = 42

model = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cpu
#
# Epoch 1/200
#     Average - Train Loss: 2.6540 | Val Loss: 2.6762
#  | Accuracy: 22.00%
# Epoch 2/200
#     Average - Train Loss: 2.6531 | Val Loss: 2.6721
#  | Accuracy: 23.00%
# Epoch 3/200
#     Average - Train Loss: 2.6477 | Val Loss: 2.6527
#  | Accuracy: 21.00%
# Epoch 4/200
#     Average - Train Loss: 2.6342 | Val Loss: 2.6112
#  | Accuracy: 22.00%
# Epoch 5/200
#     Average - Train Loss: 2.6131 | Val Loss: 2.5997
#  | Accuracy: 23.00%
# Epoch 6/200
#     Average - Train Loss: 2.6062 | Val Loss: 2.5928
#  | Accuracy: 22.00%
# Epoch 7/200
#     Average - Train Loss: 2.6201 | Val Loss: 2.5845
#  | Accuracy: 23.00%
# Epoch 8/200
#     Average - Train Loss: 2.5787 | Val Loss: 2.5801
#  | Accuracy: 23.00%
# Epoch 9/200
#     Average - Train Loss: 2.5895 | Val Loss: 2.5869
#  | Accuracy: 23.00%
# Epoch 10/200
#     Average - Train Loss: 2.5894 | Val Loss: 2.5803
#  | Accuracy: 23.00%
# Epoch 11/200
# ...

# %%
from training.training import save_model

save_model(model, "v2")
# Out:
# ✅ Modelo guardado en /home/oscar/Escritorio/CPMP-Framework/models/v2.pth
